# %%
import pandas as pd

# %%
df = pd.read_csv('data/total physician.csv')

# %%
df.head()
# Out:
#       Unnamed: 0        Unnamed: 1                Unnamed: 2  \
# 0            NaN  Total Population  Total Active Physicians*
# 1            NaN               NaN                    Number
# 2  United States       328,239,523                   940,254
# 3        Alabama         4,903,185                    10,983
# 4         Alaska           731,545                     2,101
#
#          Unnamed: 3 Unnamed: 4  Unnamed: 5        Unnamed: 6  Unnamed: 7  \
# 0               NaN        NaN  Active MDs               NaN  Active DOs
# 1  Rate per 100,000       Rank      Number  Rate per 100,000      Number
# 2             286.5       N.R.     861,912             262.6      78,281
# 3             224.0         43      10,389             211.9         594
# 4             287.2         21       1,825             249.5         276
#
#          Unnamed: 8  Unnamed: 9
# 0               NaN         NaN
# 1  Rate per 100,000         NaN
# 2              23.8         NaN
# 3              12.1         NaN
# 4              37.7         NaN

# %%
df.drop(columns=['Unnamed: 9'],inplace=True)

# %%
df.head()
# Out:
#       Unnamed: 0        Unnamed: 1                Unnamed: 2  \
# 0            NaN  Total Population  Total Active Physicians*
# 1            NaN               NaN                    Number
# 2  United States       328,239,523                   940,254
# 3        Alabama         4,903,185                    10,983
# 4         Alaska           731,545                     2,101
#
#          Unnamed: 3 Unnamed: 4  Unnamed: 5        Unnamed: 6  Unnamed: 7  \
# 0               NaN        NaN  Active MDs               NaN  Active DOs
# 1  Rate per 100,000       Rank      Number  Rate per 100,000      Number
# 2             286.5       N.R.     861,912             262.6      78,281
# 3             224.0         43      10,389             211.9         594
# 4             287.2         21       1,825             249.5         276
#
#          Unnamed: 8
# 0               NaN
# 1  Rate per 100,000
# 2              23.8
# 3              12.1
# 4              37.7

# %%
df.drop(columns=['Unnamed: 4'], inplace=True)

# %%
df.head()
# Out:
#       Unnamed: 0        Unnamed: 1                Unnamed: 2  \
# 0            NaN  Total Population  Total Active Physicians*
# 1            NaN               NaN                    Number
# 2  United States       328,239,523                   940,254
# 3        Alabama         4,903,185                    10,983
# 4         Alaska           731,545                     2,101
#
#          Unnamed: 3  Unnamed: 5        Unnamed: 6  Unnamed: 7  \
# 0               NaN  Active MDs               NaN  Active DOs
# 1  Rate per 100,000      Number  Rate per 100,000      Number
# 2             286.5     861,912             262.6      78,281
# 3             224.0      10,389             211.9         594
# 4             287.2       1,825             249.5         276
#
#          Unnamed: 8
# 0               NaN
# 1  Rate per 100,000
# 2              23.8
# 3              12.1
# 4              37.7

# %%
df = df.drop(df.index[-1])

# %%
df = df.drop(df.index[:3])

# %%
df = df.reset_index(drop=True)

# %%
df = df.drop(df.index[39])

# %%
df = df.reset_index(drop=True)

# %%
# rankings_pd.rename(columns = {'test':'TEST'}, inplace = True)
df.rename(columns={
    'Unnamed: 0':'States',
    'Unnamed: 1':'Population',
    'Unnamed: 2':'Physicians',
    'Unnamed: 3':'Physicians Rate',
    'Unnamed: 5':'Active MO',
    'Unnamed: 6':'Active MO Rate',
    'Unnamed: 7':'Active DO',
    'Unnamed: 8':'Active DO Rate'
}, inplace=True)

# %%
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#        States  Population Physicians Physicians Rate Active MO Active MO Rate  \
# 0     Alabama   4,903,185     10,983           224.0    10,389          211.9
# 1      Alaska     731,545      2,101           287.2     1,825          249.5
# 2     Arizona   7,278,717     18,343           252.0    15,989          219.7
# 3    Arkansas   3,017,804      6,500           215.4     6,132          203.2
# 4  California  39,512,223    113,718           287.8   107,383          271.8
#
#   Active DO Active DO Rate
# 0       594           12.1
# 1       276           37.7
# 2     2,353           32.3
# 3       368           12.2
# 4     6,333           16.0

# %%
df.to_csv('Data/cleaned_total_physician',index=False)

# %%
pd.read_csv('Data/cleaned_total_physician')
# Out:
#                   States  Population Physicians  Physicians Rate Active MO  \
# 0                Alabama   4,903,185     10,983            224.0    10,389
# 1                 Alaska     731,545      2,101            287.2     1,825
# 2                Arizona   7,278,717     18,343            252.0    15,989
# 3               Arkansas   3,017,804      6,500            215.4     6,132
# 4             California  39,512,223    113,718            287.8   107,383
# 5               Colorado   5,758,736     16,956            294.4    15,270
# 6            Connecticut   3,565,287     12,977            364.0    12,453
# 7               Delaware     973,764      2,850            292.7     2,484
# 8   District of Columbia     705,749      6,147            871.0     5,992
# 9                Florida  21,477,737     58,822            273.9    53,328
# 10               Georgia  10,617,423     25,072            236.1    23,832
# 11                Hawaii   1,415,872      4,557            321.9     4,293
# 12                 Idaho   1,787,065      3,504            196.1     2,973
# 13              Illinois  12,671,821     37,122            292.9    34,485
# 14               Indiana   6,732,219     15,918            236.4    14,662
# 15                  Iowa   3,155,070      7,056            223.6     5,669
# 16                Kansas   2,913,314      6,874            236.0     6,054
# 17              Kentucky   4,467,673     10,528            235.6     9,758
# 18             Louisiana   4,648,794     12,557            270.1    12,261
# 19                 Maine   1,344,212      4,459            331.7     3,691
# 20              Maryland   6,045,680     23,791            393.5    22,915
# 21         Massachusetts   6,892,503     32,116            466.0    31,123
# 22              Michigan   9,986,857     30,040            300.8    24,534
# 23             Minnesota   5,639,632     17,617            312.4    16,702
# 24           Mississippi   2,976,149      5,857            196.8     5,370
# 25              Missouri   6,137,428     18,297            298.1    14,888
# 26               Montana   1,068,778      2,750            257.3     2,474
# 27              Nebraska   1,934,408      4,820            249.2     4,537
# 28                Nevada   3,080,156      6,731            218.5     5,648
# 29         New Hampshire   1,359,711      4,391            322.9     3,996
# 30            New Jersey   8,882,190     27,832            313.3    24,622
# 31            New Mexico   2,096,829      5,269            251.3     4,929
# 32              New York  19,453,561     75,749            389.4    71,442
# 33        North Carolina  10,488,084     27,650            263.6    26,024
# 34          North Dakota     762,062      1,826            239.6     1,722
# 35                  Ohio  11,689,100     35,333            302.3    30,747
# 36              Oklahoma   3,956,971      8,293            209.6     6,474
# 37                Oregon   4,217,737     13,127            311.2    12,084
# 38          Pennsylvania  12,801,989     42,051            328.5    36,134
# 39          Rhode Island   1,059,361      4,063            383.5     3,805
# 40        South Carolina   5,148,714     12,197            236.9    11,364
# 41          South Dakota     884,659      2,214            250.3     2,017
# 42             Tennessee   6,829,174     17,687            259.0    16,722
# 43                 Texas  28,995,881     67,182            231.7    62,219
# 44                  Utah   3,205,958      7,198            224.5     6,515
# 45               Vermont     623,989      2,410            386.2     2,312
# 46              Virginia   8,535,519     22,874            268.0    21,378
# 47            Washington   7,614,893     21,731            285.4    20,282
# 48         West Virginia   1,792,147      4,914            274.2     4,112
# 49             Wisconsin   5,822,434     15,975            274.4    14,817
# 50               Wyoming     578,759      1,225            211.7     1,081
#
#     Active MO Rate Active DO  Active DO Rate
# 0            211.9       594            12.1
# 1            249.5       276            37.7
# 2            219.7     2,353            32.3
# 3            203.2       368            12.2
# 4            271.8     6,333            16.0
# 5            265.2     1,685            29.3
# 6            349.3       523            14.7
# 7            255.1       366            37.6
# 8            849.0       154            21.8
# 9            248.3     5,486            25.5
# 10           224.5     1,237            11.7
# 11           303.2       264            18.6
# 12           166.4       531            29.7
# 13           272.1     2,630            20.8
# 14           217.8     1,255            18.6
# 15           179.7     1,387            44.0
# 16           207.8       820            28.1
# 17           218.4       770            17.2
# 18           263.7       296             6.4
# 19           274.6       768            57.1
# 20           379.0       876            14.5
# 21           451.5       990            14.4
# 22           245.7     5,499            55.1
# 23           296.2       915            16.2
# 24           180.4       487            16.4
# 25           242.6     3,408            55.5
# 26           231.5       276            25.8
# 27           234.5       283            14.6
# 28           183.4     1,083            35.2
# 29           293.9       395            29.1
# 30           277.2     3,208            36.1
# 31           235.1       340            16.2
# 32           367.2     4,300            22.1
# 33           248.1     1,626            15.5
# 34           226.0       104            13.6
# 35           263.0     4,583            39.2
# 36           163.6     1,815            45.9
# 37           286.5     1,042            24.7
# 38           282.3     5,916            46.2
# 39           359.2       257            24.3
# 40           220.7       833            16.2
# 41           228.0       197            22.3
# 42           244.9       965            14.1
# 43           214.6     4,960            17.1
# 44           203.2       683            21.3
# 45           370.5        98            15.7
# 46           250.5     1,494            17.5
# 47           266.3     1,449            19.0
# 48           229.4       801            44.7
# 49           254.5     1,158            19.9
# 50           186.8       144            24.9
