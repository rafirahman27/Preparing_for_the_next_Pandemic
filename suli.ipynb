# %%
import pandas as pd

# %%
df = pd.read_csv('data/total physician.csv')

# %%
df
# Out:
#               Unnamed: 0        Unnamed: 1                Unnamed: 2  \
# 0                    NaN  Total Population  Total Active Physicians*
# 1                    NaN               NaN                    Number
# 2          United States       328,239,523                   940,254
# 3                Alabama         4,903,185                    10,983
# 4                 Alaska           731,545                     2,101
# 5                Arizona         7,278,717                    18,343
# 6               Arkansas         3,017,804                     6,500
# 7             California        39,512,223                   113,718
# 8               Colorado         5,758,736                    16,956
# 9            Connecticut         3,565,287                    12,977
# 10              Delaware           973,764                     2,850
# 11  District of Columbia           705,749                     6,147
# 12               Florida        21,477,737                    58,822
# ...
