# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # State Level Models

# %%
state_data = pd.read_csv('../Data/merged_state_final.csv')
state_data.head()
# Out:
#      Location  Employment_2020  Employment_2021  Employment_2022  \
# 0     Alabama          2671005          2769464          2869931
# 1      Alaska           430840           443047           457687
# 2     Arizona          3920033          4086802          4287595
# 3    Arkansas          1639829          1686444          1755536
# 4  California         23154091         23934549         25300974
#
#    Inc_Per_Cap_2020  Inc_Per_Cap_2021  Inc_Per_CAp_2022  Life_Exp_2020  \
# 0             45887             50059             50916           73.2
# 1             61898             65662             68635           76.6
# 2             52133             56420             58442           76.3
# 3             47147             51636             52618           73.8
# 4             70061             76991             77036           79.0
#
#    Life_Exp_2019  Life_Exp_2018  ...  Yes, 50 or more people  all_causes_2020  \
# 0           75.2           75.1  ...                    1.00             9021
# 1           77.7           78.0  ...                    0.00              545
# 2           78.8           78.7  ...                    2.89            13186
# 3           75.7           75.6  ...                    1.00             4992
# 4           80.9           80.8  ...                    1.18            41279
#
#    all_causes_2021  all_causes_2022  covid_2020  covid_2021  covid_2022  \
# 0            13018             6246        6337        9771        3933
# 1             1429              686         213         804         275
# 2            17961             8835        8603       13536        5849
# 3             6908             3854        3691        5333        2593
# 4            60680            36786       29962       48834       21158
#
#    Covid_pop_perce_2020  Covid_pop_perce_2021  Covid_pop_perce_2022
# 0              0.001261              0.001945              0.000783
# 1              0.000290              0.001096              0.000375
# 2              0.001203              0.001893              0.000818
# 3              0.001226              0.001771              0.000861
# 4              0.000758              0.001235              0.000535
#
# [5 rows x 123 columns]

# %% [markdown]
# ### Y = Excess Deaths

# %%
X1 = state_data.drop(columns=['Location', 'Mask_Mandate','Exc_deaths_2017', 'Exc_deaths_2018','Exc_deaths_2019',
                              'Exc_deaths_2020', 'Exc_deaths_2021','Exc_deaths_2022',
                      'all_causes_2020', 'all_causes_2021', 'all_causes_2022', 'covid_2020',
                      'covid_2021', 'covid_2022', 'Covid_pop_perce_2020', 'Covid_pop_perce_2021',
                     'Covid_pop_perce_2022'])
y1 = state_data[['Exc_deaths_2020', 'Exc_deaths_2021','Exc_deaths_2022']]

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, random_state=42)

# %%
state_lr = LinearRegression()
state_lr.fit(X1_train, y1_train)
state_lr.score(X1_train, y1_train), state_lr.score(X1_test, y1_test)
# Out:
# (1.0, 0.8032811801244987)

# %% [markdown]
# ### Y= Covid Deaths

# %%
y2 = state_data[['covid_2020', 'covid_2021', 'covid_2022']]
X2_train, X2_test, y2_train, y2_test = train_test_split(X1, y2, random_state=42)

# %%
state_lr2 = LinearRegression()
state_lr2.fit(X2_train, y2_train)
state_lr2.score(X2_train, y2_train), state_lr2.score(X2_test, y2_test)
# Out:
# (1.0, 0.8804713015012814)

# %% [markdown]
# # County Level Models

# %%
county_data = pd.read_csv('../Data/Cleaned/county_df3.csv')
county_data.head()
# Out:
#    FIPS_x  Years of Potential Life Lost Rate (premature death)  \
# 0    1001                                             8824.0
# 1    1003                                             7225.0
# 2    1005                                             9586.0
# 3    1007                                            11784.0
# 4    1009                                            10908.0
#
#    % Fair/Poor Health  percent_smokers  percent_obese  Food Environment Index  \
# 0                  18               19             38                     7.2
# 1                  18               17             31                     8.0
# 2                  26               22             44                     5.6
# 3                  20               20             38                     7.6
# 4                  21               20             34                     8.5
#
#    % Physically Inactive  percent Excessive Drinking  PCP Rate  \
# 0                     31                          17      42.0
# 1                     24                          17      73.0
# 2                     28                          13      39.0
# 3                     35                          16      57.0
# 4                     29                          15      23.0
#
#    Preventable Hosp stays Rate  ...  percent Non-Hispanic White  \
# 0                       6599.0  ...                        74.5
# 1                       3833.0  ...                        83.0
# 2                       4736.0  ...                        46.0
# 3                       5998.0  ...                        74.3
# 4                       4162.0  ...                        86.9
#
#    percent Not Proficient in English  percent Female  number Rural  Masks  \
# 0                                  1            51.3       22921.0  267.0
# 1                                  0            51.5       77060.0  267.0
# 2                                  1            47.2       18613.0  267.0
# 3                                  0            46.5       15663.0  267.0
# 4                                  2            50.7       51562.0  267.0
#
#    Administered_Dose1_Pop_Pct  Administered_Dose1_Recip_65PlusPop_Pct  water  \
# 0                        42.2                                    73.8      0
# 1                        53.2                                    89.9      1
# 2                        44.5                                    75.3      0
# 3                        36.6                                    64.2      0
# 4                        31.9                                    56.6      0
#
#      cases  deaths
# 0  18961.0   230.0
# 1  67496.0   719.0
# 2   7027.0   103.0
# 3   7692.0   108.0
# 4  17731.0   260.0
#
# [5 rows x 48 columns]

# %% [markdown]
# ### Y = Number of Cases

# %%
y3 = county_data['cases']
X3 = county_data.drop(columns = ['cases', 'deaths'])

X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, random_state = 42)

# %%
lr_county_cases = LinearRegression()
lr_county_cases.fit(X3_train, y3_train)

print(f'Train Score: {lr_county_cases.score(X3_train, y3_train)}')
print(f'Test Score: {lr_county_cases.score(X3_test, y3_test)}')
# Out:
# Train Score: 0.965103481631993
# Test Score: 0.9300157319353011

# %%
pd.DataFrame(set(zip(X3.columns, lr_county_cases.coef_)), columns = ['Variable Name',
                                    'Coefficient']).sort_values('Coefficient').round(1)
# Out:
#                                         Variable Name  Coefficient
# 34     percent Native Hawaiian/Other Pacific Islander      -3284.7
# 41                                 Percent Unemployed      -1391.2
# 13                                    percent_smokers       -801.3
# 7                                 Average Daily PM2.5       -693.3
# 6                                      percent Female       -420.7
# 26                         percent Excessive Drinking       -389.4
# 24                           Percent Uninsured Adults       -324.8
# 8                                 percent 65 and over       -264.3
# 3                                       percent_obese       -251.1
# 14                         Percent Uninsured children       -241.1
# 4                         High School Graduation Rate       -190.5
# 38                              Percent Food Insecure       -154.1
# 32                         Administered_Dose1_Pop_Pct       -121.0
# 9                               Inadequate Facilities       -111.0
# 22                                      percent Asian        -92.7
# 43                      Segregation index black/white        -82.4
# 42                             Percent Vaccinated Flu        -11.0
# 16                                           PCP Rate         -9.9
# 21                                              Masks         -6.1
# 18                            Median Household Income         -0.2
# 0                                        number Rural          0.0
# 1                         Preventable Hosp stays Rate          0.1
# 17                                             FIPS_x          0.1
# 44                                         Population          0.3
# 11  Years of Potential Life Lost Rate (premature d...          0.3
# 20                                HIV Prevalence Rate          1.0
# 33                             Food Environment Index         25.4
# 35                 Segregation Index non-white/ white         25.4
# 37                    Percent Severe Housing Problems         47.3
# 19                  percent Not Proficient in English         54.3
# 40             Administered_Dose1_Recip_65PlusPop_Pct         88.5
# 39                                   Percent Diabetic        151.9
# 29                               Percent Some College        238.8
# 30                                       Income Ratio        348.4
# 45                                       percent < 18        371.1
# 36                                 % Fair/Poor Health        397.5
# 10                         Severe Housing Cost Burden        398.6
# 12                              % Physically Inactive        717.0
# 2                                        Overcrowding        857.9
# 15                         Percent Insufficient Sleep        933.8
# 31                                    Life Expectancy       1319.1
# 5                            percent African American       1862.6
# 27                                   percent Hispanic       1993.6
# 28                         percent Non-Hispanic White       2087.1
# 23             percent American Indian/Alaskan Native       2189.1
# 25                                              water       2453.4

# %% [markdown]
# ### Y = Deaths

# %%
y4 = county_data['deaths']
X4 = county_data.drop(columns = ['cases', 'deaths'])

# TTS
X4_train, X4_test, y4_train, y4_test = train_test_split(X4, y4, random_state = 42)

# %%
lr_county_deaths = LinearRegression()
lr_county_deaths.fit(X4_train, y4_train)

print(f'Train Score: {lr_county_deaths.score(X4_train, y4_train)}')
print(f'Test Score: {lr_county_deaths.score(X4_test, y4_test)}')
# Out:
# Train Score: 0.9311952481411998
# Test Score: 0.9076835801444738

# %%
pd.DataFrame(set(zip(X4.columns, lr_county_deaths.coef_)), columns = ['Variable Name',
                                    'Coefficient']).sort_values('Coefficient').round(1)
# Out:
#                                         Variable Name  Coefficient
# 5      percent Native Hawaiian/Other Pacific Islander       -197.3
# 9                              Food Environment Index        -30.5
# 7                               Percent Food Insecure        -23.1
# 4                                  % Fair/Poor Health        -17.8
# 39                              Inadequate Facilities        -11.4
# 1                                        Income Ratio         -7.3
# 31                                Average Daily PM2.5         -5.8
# 15                         Administered_Dose1_Pop_Pct         -4.1
# 43                         percent Excessive Drinking         -3.4
# 23                                 Percent Unemployed         -3.0
# 40                           Percent Uninsured Adults         -2.0
# 28                                    percent_smokers         -1.7
# 24                                   Percent Diabetic         -1.3
# 13                                      percent Asian         -0.3
# 0                         High School Graduation Rate         -0.1
# 35                                              Masks         -0.1
# 42                            Median Household Income         -0.0
# 14                                       number Rural         -0.0
# 11                                             FIPS_x         -0.0
# 19                                         Population          0.0
# 27                        Preventable Hosp stays Rate          0.0
# 26  Years of Potential Life Lost Rate (premature d...          0.0
# 25                                           PCP Rate          0.0
# 21                                HIV Prevalence Rate          0.2
# 18                      Segregation index black/white          0.6
# 38                             Percent Vaccinated Flu          1.1
# 45                 Segregation Index non-white/ white          1.4
# 10                                      percent_obese          1.7
# 36             Administered_Dose1_Recip_65PlusPop_Pct          2.0
# 34                                     percent Female          2.6
# 37                         Percent Uninsured children          3.2
# 41                               Percent Some College          4.8
# 12                    Percent Severe Housing Problems          6.1
# 20                                       Overcrowding          7.4
# 29                                       percent < 18         12.0
# 17                                percent 65 and over         13.0
# 6                   percent Not Proficient in English         14.5
# 30                         Severe Housing Cost Burden         15.1
# 44                              % Physically Inactive         17.2
# 3                                     Life Expectancy         17.3
# 16                           percent African American         25.9
# 32                         Percent Insufficient Sleep         27.5
# 8                          percent Non-Hispanic White         27.8
# 22                                   percent Hispanic         29.0
# 33             percent American Indian/Alaskan Native         33.4
# 2                                               water         50.8
