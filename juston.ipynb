# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Population

# %%
# find population of state,find total pop of county, percent of of the county pop to the state

# %%
pop = pd.read_csv('./Ignore/covid_county_population_usafacts.csv')

# %%
pop.describe()
# Out:
#          countyFIPS    population
# count   3195.000000  3.195000e+03
# mean   29882.220970  1.027354e+05
# std    15524.479302  3.309477e+05
# min        0.000000  0.000000e+00
# 25%    18098.000000  1.039950e+04
# 50%    29123.000000  2.512700e+04
# 75%    45054.000000  6.694150e+04
# max    56045.000000  1.003911e+07

# %%
pop.head()
# Out:
#    countyFIPS            County Name State  population
# 0           0  Statewide Unallocated    AL           0
# 1        1001         Autauga County    AL       55869
# 2        1003         Baldwin County    AL      223234
# 3        1005         Barbour County    AL       24686
# 4        1007            Bibb County    AL       22394

# %%
# States dic
state_name = {
    'AL':'Alabama',
    'AK':'Alaska',
    'AZ':'Arizona',
    'AR':'Arkansas',
    'CA':'California',
    'CO':'Colorado',
    'CT':'Connecticut',
    'DE':'Delaware',
    'DC':'District of Columbia',
    'FL':'Florida',
    'GA':'Georgia',
    'HI':'Hawaii',
    'ID':'Idaho',
    'IL':'Illinois',
    'IN':'Indiana',
    'IA':'Iowa',
    'KS':'Kansas',
    'KY':'Kentucky',
    'LA':'Louisiana',
    'ME':'Maine',
    'MD':'Maryland',
    'MA':'Massachusetts',
    'MI':'Michigan',
    'MN':'Minnesota',
    'MS':'Mississippi',
    'MO':'Missouri',
    'MT':'Montana',
    'NE':'Nebraska',
    'NV':'Nevada',
    'NH':'New Hampshire',
    'NJ':'New Jersey',
    'NM':'New Mexico',
    'NY':'New York',
    'NC':'North Carolina',
    'ND':'North Dakota',
    'OH':'Ohio',
    'OK':'Oklahoma',
    'OR':'Oregon',
    'PA':'Pennsylvania',
    'RI':'Rhode Island',
    'SC':'South Carolina',
    'SD':'South Dakota',
    'TN':'Tennessee',
    'TX':'Texas',
    'UT':'Utah',
    'VT':'Vermont',
    'VA':'Virginia',
    'WA':'Washington',
    'WV':'West Virginia',
    'WI':'Wisconsin',
    'WY':'Wyoming'
}

# %%
state_pop_sum = {}
for index, row in pop.iterrows():
    state_abbr = row['State'] 
    tot_pop = row['population']  
    
    if state_abbr in state_pop_sum:
        state_pop_sum[state_abbr] += tot_pop
    else:
        state_pop_sum[state_abbr] = tot_pop

for state, pop_sum in state_pop_sum.items():
    print(f"{state}: {pop_sum}")
# Out:
# AL: 4903185
# AK: 731545
# AZ: 7278717
# AR: 3017804
# CA: 39512223
# CO: 5758736
# CT: 3565287
# DE: 973764
# DC: 705749
# FL: 21477737
# GA: 10617423
# HI: 1415872
# ID: 1787065
# IL: 12671821
# IN: 6732219
# IA: 3155070
# KS: 2913314
# KY: 4467673
# LA: 4648794
# ME: 1344212
# MD: 6045680
# MA: 6892503
# MI: 9986857
# MN: 5639632
# MS: 2976149
# MO: 6137428
# MT: 1068778
# NE: 1934408
# NV: 3080156
# NH: 1359711
# NJ: 8882190
# NM: 2096829
# NY: 19453561
# NC: 10488084
# ND: 762062
# OH: 11689100
# OK: 3956971
# OR: 4217737
# PA: 12801989
# RI: 1059361
# SC: 5148714
# SD: 884659
# TN: 6829174
# TX: 28995881
# UT: 3205958
# VT: 623989
# VA: 8535519
# WA: 7614893
# WV: 1792147
# WI: 5822434
# WY: 578759

# %%
tot_pop = pd.DataFrame(list(state_pop_sum.items()), columns=['State', 'Total Population'])
tot_pop.head()
# Out:
#   State  Total Population
# 0    AL           4903185
# 1    AK            731545
# 2    AZ           7278717
# 3    AR           3017804
# 4    CA          39512223

# %%
merged_pop = pd.merge(pop, tot_pop, on='State')
merged_pop.head()
# Out:
#    countyFIPS            County Name State  population  Total Population
# 0           0  Statewide Unallocated    AL           0           4903185
# 1        1001         Autauga County    AL       55869           4903185
# 2        1003         Baldwin County    AL      223234           4903185
# 3        1005         Barbour County    AL       24686           4903185
# 4        1007            Bibb County    AL       22394           4903185

# %%
merged_pop['pop %'] = (merged_pop['population'] / merged_pop['Total Population'])*100
merged_pop.head()
# Out:
#    countyFIPS            County Name State  population  Total Population  \
# 0           0  Statewide Unallocated    AL           0           4903185
# 1        1001         Autauga County    AL       55869           4903185
# 2        1003         Baldwin County    AL      223234           4903185
# 3        1005         Barbour County    AL       24686           4903185
# 4        1007            Bibb County    AL       22394           4903185
#
#       pop %
# 0  0.000000
# 1  1.139443
# 2  4.552837
# 3  0.503469
# 4  0.456724

# %%
#population data Frame
merged_pop.to_csv('./Data/population_w_percent.csv', index = False)

# %%
new_pop = pd.read_csv('./Data/population_w_percent.csv')

# %%
new_pop.head()
# Out:
#    countyFIPS            County Name State  population  Total Population  \
# 0           0  Statewide Unallocated    AL           0           4903185
# 1        1001         Autauga County    AL       55869           4903185
# 2        1003         Baldwin County    AL      223234           4903185
# 3        1005         Barbour County    AL       24686           4903185
# 4        1007            Bibb County    AL       22394           4903185
#
#       pop %
# 0  0.000000
# 1  1.139443
# 2  4.552837
# 3  0.503469
# 4  0.456724

# %%
new_pop.isna().sum()
# Out:
# countyFIPS          0
# County Name         0
# State               0
# population          0
# Total Population    0
# pop %               0
# dtype: int64

# %%
new_pop['pop %'] = new_pop['pop %']/100

# %%
pop_perc = new_pop[['countyFIPS','pop %']]
pop_perc = pd.DataFrame(pop_perc)

# %% [markdown]
# # Confirmed Cases

# %%
cases = pd.read_csv('./Data/county_fips.csv')
cases.head()
# Out:
#    Unnamed: 0  countyFIPS            County Name State
# 0           0           0  Statewide Unallocated    AL
# 1           1        1001        Autauga County     AL
# 2           2        1003        Baldwin County     AL
# 3           3        1005        Barbour County     AL
# 4           4        1007           Bibb County     AL

# %%
cases = pd.merge(cases, pop_perc, how = 'left', on='countyFIPS').copy()
cases
# Out:
#         Unnamed: 0  countyFIPS            County Name State   pop %_x  \
# 0                0           0  Statewide Unallocated    AL  0.000000
# 1                0           0  Statewide Unallocated    AL  0.000000
# 2                0           0  Statewide Unallocated    AL  0.000000
# 3                0           0  Statewide Unallocated    AL  0.000000
# 4                0           0  Statewide Unallocated    AL  0.000000
# ...            ...         ...                    ...   ...       ...
# 135788        3188       56037     Sweetwater County     WY  0.073162
# 135789        3189       56039          Teton County     WY  0.040542
# 135790        3190       56041          Uinta County     WY  0.034947
# 135791        3191       56043       Washakie County     WY  0.013486
# 135792        3192       56045         Weston County     WY  0.011969
#
#          pop %_y
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# ...          ...
# 135788  0.073162
# 135789  0.040542
# 135790  0.034947
# 135791  0.013486
# 135792  0.011969
#
# [135793 rows x 6 columns]

# %%
cases_2020 = cases[['countyFIPS', 'County', 'State', 'StateFIPS', '2020-12-31', 'pop %']].copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 cases_2020 = cases[['countyFIPS', 'County', 'State', 'StateFIPS', '2020-12-31', 'pop %']].copy()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['County', 'StateFIPS', '2020-12-31'] not in index"

# %%
cases_test = cases[['countyFIPS', 'County', 'State', 'StateFIPS', '2020-12-31', 'pop %']].copy()

# %%
cases_2020.rename(columns = {'2020-12-31': 'cases_2020', 'pop %': 'pop_per'}, inplace =True)

# %%
cases_2020.head()

# %% [markdown]
# # Deaths by Day

# %%
deaths = pd.read_csv('./Ignore/covid_deaths_usafacts.csv')
deaths

# %%
for state, abrv in state_list:
    state_abrv 
    pop['population'] == sum(county['population'] if county['State'] == state_abrv)
